# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot

# %%
arrest_data = pd.read_csv('NYPD_Arrest_Data__Year_to_Date_.csv')

# %%
arrest_data.head(5)
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0   230210509  06/29/2021  105.0               STRANGULATION 1ST  106.0
# 1   226147627  03/26/2021  177.0                    SEXUAL ABUSE  116.0
# 2   226113029  03/25/2021  101.0                       ASSAULT 3  344.0
# 3   225789182  03/18/2021  101.0                       ASSAULT 3  344.0
# 4   229613603  06/16/2021  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
#
#                       OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0                FELONY ASSAULT  PL 1211200          F           Q
# 1                    SEX CRIMES  PL 1306501          F           M
# 2  ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           K
# 3  ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           B
# 4                       ROBBERY  PL 1601504          F           K
#
#    ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX PERP_RACE  \
# ...

# %%
arrest_data.tail(5)
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 74238   227732186  05/05/2021  729.0  FORGERY,ETC.,UNCLASSIFIED-FELO  113.0
# 74239   226941620  04/14/2021  672.0                          RIOT 1  126.0
# 74240   226955429  04/15/2021  779.0  PUBLIC ADMINISTRATION,UNCLASSI  126.0
# 74241   227539475  04/29/2021  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 74242   227112255  04/19/2021  705.0              FORGERY,ETC.-MISD.  358.0
#
#                       OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 74238                   FORGERY  PL 1703000          F           Q
# 74239   MISCELLANEOUS PENAL LAW  PL 2400601          F           M
# 74240   MISCELLANEOUS PENAL LAW  PL 215510B          F           M
# 74241             PETIT LARCENY  PL 1552500          M           B
# 74242  OFFENSES INVOLVING FRAUD  PL 1700500          M           K
#
#        ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX PERP_RACE  \
# ...

# %%
arrest_data.shape
# Out:
# (74243, 19)

# %%
arrest_data.dtypes
# Out:
# ARREST_KEY                    int64
# ARREST_DATE                  object
# PD_CD                       float64
# PD_DESC                      object
# KY_CD                       float64
# OFNS_DESC                    object
# LAW_CODE                     object
# LAW_CAT_CD                   object
# ARREST_BORO                  object
# ARREST_PRECINCT               int64
# JURISDICTION_CODE             int64
# AGE_GROUP                    object
# PERP_SEX                     object
# PERP_RACE                    object
# X_COORD_CD                    int64
# Y_COORD_CD                    int64
# Latitude                    float64
# Longitude                   float64
# New Georeferenced Column     object
# dtype: object

# %%
arrest_data.sort_values(by='PD_DESC').head(5) #first 5 rows of the dataset by PD_DESC
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD               PD_DESC  KY_CD  \
# 42069   222840072  01/09/2021  466.0  ACCOSTING,FRAUDULENT  238.0
# 39613   222840074  01/09/2021  466.0  ACCOSTING,FRAUDULENT  238.0
# 73024   227819683  05/06/2021  466.0  ACCOSTING,FRAUDULENT  238.0
# 55773   229363275  06/10/2021  466.0  ACCOSTING,FRAUDULENT  238.0
# 71161   227676538  05/03/2021  466.0  ACCOSTING,FRAUDULENT  238.0
#
#                   OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 42069  FRAUDULENT ACCOSTING  PL 1653001          M           M
# 39613  FRAUDULENT ACCOSTING  PL 1653001          M           M
# 73024  FRAUDULENT ACCOSTING  PL 1653001          M           B
# 55773  FRAUDULENT ACCOSTING  PL 1653001          M           B
# 71161  FRAUDULENT ACCOSTING  PL 1653001          M           M
#
#        ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX PERP_RACE  \
# 42069               14                  0     45-64        M     WHITE
# ...
